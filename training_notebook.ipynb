# %%
import joblib

# pipe = Pipeline(steps=[("preprocess", preprocessor), ("model", rf)])
joblib.dump(pipe, "immo_eliza_rf_small.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import joblib
#       3 # pipe = Pipeline(steps=[("preprocess", preprocessor), ("model", rf)])
# ----> 4 joblib.dump(pipe, "immo_eliza_rf_small.joblib")
#
# NameError: name 'pipe' is not defined
